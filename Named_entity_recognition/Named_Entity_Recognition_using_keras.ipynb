# %% [markdown]
# # Named Entity Recognition using LSTMs with Keras

# %% [markdown]
# ###  Importing Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.3.0
# GPU detected: []

# %% [markdown]
# ### Task 2: Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### Retrieving Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ###  Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'damages': 1,
#  'location': 2,
#  'Burn': 3,
#  'conflict-resolution': 4,
#  'Salman': 5,
#  'boundaries': 6,
#  'increases': 7,
#  'nationally': 8,
#  'script': 9,
#  'Challenges': 10,
#  'Shahawar': 11,
#  'land-use': 12,
#  'inflicted': 13,
#  'percent': 14,
#  'Notari': 15,
#  'Clerq': 16,
#  'gall': 17,
#  'Disasters': 18,
#  '1500': 19,
#  '1631': 20,
#  '463': 21,
#  'Sekou': 22,
#  'CIS': 23,
#  'Erin': 24,
#  'gruesome': 25,
#  'Gatlin': 26,
#  'faiths': 27,
#  '2,46,000': 28,
#  'Illinois': 29,
#  'Phukphasuk': 30,
#  'Whales': 31,
#  'steel': 32,
#  'ecology': 33,
#  'Christman': 34,
#  'recoverable': 35,
#  'preoccupied': 36,
#  'sought': 37,
#  'seizing': 38,
#  'Jebaliya': 39,
#  'injection': 40,
#  'Meadowbrook': 41,
#  'materials': 42,
#  'Bernal': 43,
#  'longest': 44,
#  'Housedog': 45,
#  'sooner': 46,
#  'Ghanaian': 47,
#  'Mexicali': 48,
#  'video-conferencing': 49,
#  'rebates': 50,
#  'Chitigov': 51,
#  'Bakwa': 52,
#  'Coca': 53,
#  'Hajime': 54,
#  'unlicensed': 55,
#  'Qiyue': 56,
#  'foundations': 57,
#  'sessions': 58,
#  'picnicking': 59,
#  'Yorker': 60,
#  'blew': 61,
#  'Are': 62,
#  'bass': 63,
#  'Cassini': 64,
#  'factions': 65,
#  'Socialists': 66,
#  'selective': 67,
#  '43-year-old': 68,
#  'Cancer': 69,
#  '14.5': 70,
#  'premeditated': 71,
#  'Marigat': 72,
#  'cheapest': 73,
#  '747': 74,
#  'Making': 75,
#  'Mujahadeen': 76,
#  'bless': 77,
#  'roams': 78,
#  'Pakistani-sponsored': 79,
#  'top-ranked': 80,
#  'servant': 81,
#  'ai': 82,
#  'G-7': 83,
#  'resignations': 84,
#  'abated': 85,
#  'writes': 86,
#  '117': 87,
#  'Keeping': 88,
#  'Longtime': 89,
#  'unaffected': 90,
#  'aggressive': 91,
#  'Khz': 92,
#  '85.7': 93,
#  'english': 94,
#  'Vlore': 95,
#  'devils': 96,
#  'timelines': 97,
#  'Smoky': 98,
#  'Richie': 99,
#  'Sipah-e-Sahaba': 100,
#  'outlet': 101,
#  'Doboj': 102,
#  'Holbrooke': 103,
#  'Rehnquist': 104,
#  'Ruhpolding': 105,
#  'Monitor': 106,
#  'adherence': 107,
#  'verifiably': 108,
#  'two-wheeled': 109,
#  'versions': 110,
#  'Tidal': 111,
#  'Perwiz': 112,
#  'palm': 113,
#  'Equatoria': 114,
#  'Rupiah': 115,
#  'walled': 116,
#  'eight-nation': 117,
#  'Strelets': 118,
#  'Library': 119,
#  'Farda': 120,
#  'pollutes': 121,
#  '93,000': 122,
#  'al-Libbi': 123,
#  '628': 124,
#  'Duran': 125,
#  'one-stop': 126,
#  'left-footed': 127,
#  'Karasin': 128,
#  'pre-paid': 129,
#  'Asadollah': 130,
#  'Alizai': 131,
#  'walked': 132,
#  'whereabouts': 133,
#  '3.5': 134,
#  '50.9': 135,
#  'Murshidabad': 136,
#  'undersecretary-general': 137,
#  'Orbi': 138,
#  'applications': 139,
#  'defenseless': 140,
#  'emitted': 141,
#  'carryover': 142,
#  'renegade': 143,
#  'funding': 144,
#  '140-kilometers': 145,
#  'Foy': 146,
#  'IWC': 147,
#  'chances': 148,
#  '0.9': 149,
#  'Blaise': 150,
#  'hides': 151,
#  'frequently': 152,
#  'Besides': 153,
#  'cotton': 154,
#  'Adraskan': 155,
#  'fasted': 156,
#  'message': 157,
#  'farmyard': 158,
#  'Aslan': 159,
#  'Located': 160,
#  'excluded': 161,
#  '1887': 162,
#  'Megan': 163,
#  'Shallah': 164,
#  'Despres': 165,
#  '15-kilometer': 166,
#  'pay': 167,
#  '1.294': 168,
#  'Self-interest': 169,
#  'Banja': 170,
#  'disciplines': 171,
#  'lowering': 172,
#  'Soviet-dominated': 173,
#  'week-long': 174,
#  'Ayar': 175,
#  'carnival-like': 176,
#  'fallen': 177,
#  'trace': 178,
#  'Angelo': 179,
#  'Serena': 180,
#  'Hormuz': 181,
#  'caters': 182,
#  'Substantial': 183,
#  'Rezko': 184,
#  'proposals': 185,
#  'U.S.-allied': 186,
#  'Through': 187,
#  'Montagnards': 188,
#  'TRYGGVASON': 189,
#  'Ouyang': 190,
#  'twigs': 191,
#  'Foreman': 192,
#  'commissioned': 193,
#  'Akrotiri': 194,
#  'Tadic': 195,
#  'Haidar': 196,
#  '11-year': 197,
#  'Katutsi': 198,
#  'reality': 199,
#  'unauthorized': 200,
#  'resettlement': 201,
#  'songwriters': 202,
#  'thrives': 203,
#  '101st': 204,
#  'Third-seeded': 205,
#  'Committees': 206,
#  'low-lying': 207,
#  'Kunpeng': 208,
#  'Olsson': 209,
#  '2-million': 210,
#  'entering': 211,
#  'JUDGE': 212,
#  'kite': 213,
#  'Lynn': 214,
#  'circumcision': 215,
#  'Hofstad': 216,
#  'Usher': 217,
#  'parents': 218,
#  'Ntini': 219,
#  'cleric': 220,
#  '19-day': 221,
#  'full-fledged': 222,
#  'Corruption': 223,
#  'industrious': 224,
#  'Okada': 225,
#  'Guatemala': 226,
#  'overthrow': 227,
#  'leisurely': 228,
#  'assessed': 229,
#  'tally': 230,
#  'Saada': 231,
#  '570': 232,
#  'SSR': 233,
#  'arraignment': 234,
#  'understanding': 235,
#  'valves': 236,
#  'Meeting': 237,
#  'Kites': 238,
#  'receded': 239,
#  'Chengdu': 240,
#  '40,00,000': 241,
#  'Burgie': 242,
#  'gain': 243,
#  'weapons': 244,
#  'Antonin': 245,
#  'tentatively': 246,
#  'piped': 247,
#  'U.S.-Mexico': 248,
#  'six-country': 249,
#  'concessions': 250,
#  'Pollsters': 251,
#  'auspices': 252,
#  'university': 253,
#  'sail': 254,
#  'Baghdadi': 255,
#  'Kapustin': 256,
#  'preclude': 257,
#  'fouled': 258,
#  'high': 259,
#  'Johnson-Sirleaf': 260,
#  'short-term': 261,
#  'state-controlled': 262,
#  'volcanos': 263,
#  'Tianjin': 264,
#  'virus': 265,
#  'country': 266,
#  'subscribers': 267,
#  'Anglo-Egyptian': 268,
#  'got': 269,
#  'Perina': 270,
#  'And': 271,
#  'coming': 272,
#  'motor': 273,
#  'military-imposed': 274,
#  'Want': 275,
#  'relentless': 276,
#  'manned': 277,
#  'beaming': 278,
#  'Uri': 279,
#  'Lago': 280,
#  'informant': 281,
#  'Vidar': 282,
#  'Yoshinori': 283,
#  'affiliate': 284,
#  'enables': 285,
#  'faulted': 286,
#  'NFL': 287,
#  'clashing': 288,
#  '51.4': 289,
#  'Parliamentarian': 290,
#  'anti-dumping': 291,
#  'pyramids': 292,
#  'strikeouts': 293,
#  'Hongdu': 294,
#  'notify': 295,
#  'displaced': 296,
#  'euro-zone': 297,
#  'proliferating': 298,
#  'explosive-laden': 299,
#  'rampage': 300,
#  'Yemenis': 301,
#  'snow': 302,
#  'Chodo': 303,
#  'Giustra': 304,
#  'arrested': 305,
#  'Blues': 306,
#  'Bian': 307,
#  'normalcy': 308,
#  'Grain': 309,
#  'welfare': 310,
#  'Myanmar': 311,
#  'wines': 312,
#  '159th': 313,
#  'demerits': 314,
#  'Lawrence': 315,
#  'regional': 316,
#  'float': 317,
#  'dangers': 318,
#  'returns': 319,
#  'Spit': 320,
#  'Petrodar': 321,
#  'boas': 322,
#  'marginalized': 323,
#  'Pervasive': 324,
#  '9,50,000': 325,
#  'Filipino': 326,
#  '11,700': 327,
#  'rankings': 328,
#  'iron': 329,
#  'incur': 330,
#  'York': 331,
#  'rate': 332,
#  'thinned': 333,
#  'incompatible': 334,
#  '12,348': 335,
#  'sculpture': 336,
#  'Album': 337,
#  'estates': 338,
#  'moves': 339,
#  'Policy': 340,
#  'fostering': 341,
#  'pinpoint': 342,
#  'beat': 343,
#  '17.3': 344,
#  'bus': 345,
#  'gradual': 346,
#  'clinic': 347,
#  'golfer': 348,
#  'cancel': 349,
#  'approximately': 350,
#  'Garden': 351,
#  'Karrada': 352,
#  'Retailing': 353,
#  '417': 354,
#  'reprisals': 355,
#  'encroachments': 356,
#  'earlier': 357,
#  'cudgelling': 358,
#  'rejected': 359,
#  'Saderat': 360,
#  'Yasir': 361,
#  'afterwards': 362,
#  'anesthesia': 363,
#  'caverns': 364,
#  'economics': 365,
#  'commend': 366,
#  'heap': 367,
#  'imagine': 368,
#  'cold-weather': 369,
#  'Ending': 370,
#  'hearty': 371,
#  'Teheran': 372,
#  'Vlado': 373,
#  'Petronas': 374,
#  'Idriz': 375,
#  'Consultative': 376,
#  'gravesite': 377,
#  'carried': 378,
#  'Gazeta': 379,
#  'expansion': 380,
#  'Al-Arabiya': 381,
#  'tile-maker': 382,
#  'deadline': 383,
#  'aired': 384,
#  'Okram': 385,
#  'Jocic': 386,
#  'Hello': 387,
#  'authoritarian': 388,
#  '8.6': 389,
#  'Emmanuel': 390,
#  'Montevideo': 391,
#  'three-vehicle': 392,
#  'exercise': 393,
#  'seventh': 394,
#  'draconian': 395,
#  'tripartite': 396,
#  'Delmas': 397,
#  'Argentina': 398,
#  'anthrax': 399,
#  '99.3': 400,
#  'oversized': 401,
#  'laboratories': 402,
#  'outlook': 403,
#  '530': 404,
#  'conditional': 405,
#  'three-phased': 406,
#  'monetary': 407,
#  'Coach': 408,
#  'PyeongChang': 409,
#  'neutralizing': 410,
#  'aneurysm': 411,
#  'removes': 412,
#  'depleting': 413,
#  'Case-Shiller': 414,
#  'marriages': 415,
#  'remember': 416,
#  'Wilma': 417,
#  'CEPA': 418,
#  '34,000': 419,
#  'cycles': 420,
#  'six-day': 421,
#  'Caliph': 422,
#  'employment': 423,
#  'redistribute': 424,
#  'furor': 425,
#  'Nicobari': 426,
#  'tuba': 427,
#  'hers': 428,
#  'chain': 429,
#  'regency': 430,
#  'await': 431,
#  'missing': 432,
#  'rafts': 433,
#  'single-party': 434,
#  'cut-off': 435,
#  'Ills': 436,
#  'discount': 437,
#  'grant': 438,
#  'Mensehra': 439,
#  'Non-Aligned': 440,
#  '1,74,000': 441,
#  'Ljoekelsoey': 442,
#  'Part': 443,
#  'deeply-flawed': 444,
#  'scourge': 445,
#  'Aviator': 446,
#  'slowdown': 447,
#  'Wal-Marts': 448,
#  'al-Bared': 449,
#  'heel': 450,
#  'proved': 451,
#  'often-stalled': 452,
#  'appeasing': 453,
#  'deposited': 454,
#  'Rebecca': 455,
#  'Zheng': 456,
#  'crowd': 457,
#  'thrift': 458,
#  'Morocco': 459,
#  'Colosseum': 460,
#  'Take': 461,
#  'Alistair': 462,
#  'repeat': 463,
#  'nearly-naked': 464,
#  'Abderrahaman': 465,
#  'appalling': 466,
#  'privacy': 467,
#  'non-functional': 468,
#  'abroad': 469,
#  'actresses': 470,
#  'immigrant': 471,
#  'militarism': 472,
#  'reproached': 473,
#  '233': 474,
#  'expect': 475,
#  'expiration': 476,
#  'Rwandan': 477,
#  'blast': 478,
#  'Raul': 479,
#  'Manuel': 480,
#  'parliament': 481,
#  'Serious': 482,
#  'cart': 483,
#  'depression': 484,
#  'hospitality': 485,
#  'blacklisted': 486,
#  'Hague-based': 487,
#  'sacrifices': 488,
#  'Garzon': 489,
#  'Shankar': 490,
#  'needy': 491,
#  'Khalid': 492,
#  'Radek': 493,
#  '117-ball': 494,
#  'extraction': 495,
#  'nom': 496,
#  'Terry': 497,
#  '100-meters': 498,
#  'member': 499,
#  'Croats': 500,
#  'Kalenga': 501,
#  'Southern': 502,
#  'Jixi-Nehe': 503,
#  'Naseem': 504,
#  'Exact': 505,
#  'Niger': 506,
#  'Highways': 507,
#  'DOGS': 508,
#  'Friesinger': 509,
#  'Chun-soo': 510,
#  'reinforcement': 511,
#  'recruiter': 512,
#  'values': 513,
#  'Crows': 514,
#  'roadblock': 515,
#  'oppress': 516,
#  'Formed': 517,
#  'speedskater': 518,
#  'Malays': 519,
#  'Enterprise': 520,
#  'Radio': 521,
#  'Orange': 522,
#  'accomplishments': 523,
#  'Yahya': 524,
#  'honest': 525,
#  'splattered': 526,
#  'bins': 527,
#  'chased': 528,
#  'sedentary': 529,
#  'Bertrand': 530,
#  'Dushanbe': 531,
#  'Hezbollah-led': 532,
#  'obstructs': 533,
#  'Ben-Eliezer': 534,
#  'Hsann': 535,
#  'antics': 536,
#  'monopolies': 537,
#  'gentle': 538,
#  '468': 539,
#  'military-police': 540,
#  'He': 541,
#  'Suez': 542,
#  'Nuristani': 543,
#  'Monsoon': 544,
#  'armada': 545,
#  'Haitian-American': 546,
#  'counter-proposal': 547,
#  'oppression': 548,
#  'Jabella': 549,
#  'tumultous': 550,
#  'Consulate': 551,
#  'investigating': 552,
#  'families': 553,
#  'overboard': 554,
#  'subsurface': 555,
#  '73,276': 556,
#  'sound': 557,
#  'briefings': 558,
#  'malnutrition': 559,
#  'Onal': 560,
#  'Bernando': 561,
#  'hot': 562,
#  'Berenson': 563,
#  'Tuncay': 564,
#  'Dying': 565,
#  'beset': 566,
#  'Jubilee': 567,
#  'English-language': 568,
#  'resilient': 569,
#  'elders': 570,
#  'military-led': 571,
#  'Unmasking': 572,
#  'immunize': 573,
#  'Injured': 574,
#  '16-year-old': 575,
#  'Heath': 576,
#  'Legislature': 577,
#  'influx': 578,
#  'presidential-parliamentary': 579,
#  'little': 580,
#  'seawater': 581,
#  'Sheiria': 582,
#  'dinar': 583,
#  'cutbacks': 584,
#  'Theyab': 585,
#  'Head': 586,
#  '385': 587,
#  'response': 588,
#  '47': 589,
#  'volunteer': 590,
#  'Delegates': 591,
#  'khz': 592,
#  'Bhagwandas': 593,
#  'Sébastien': 594,
#  'wildlife': 595,
#  'infect': 596,
#  'Alitalia': 597,
#  'levitates': 598,
#  'Shuttle': 599,
#  'Wlodzimierz': 600,
#  'walk': 601,
#  'much-needed': 602,
#  'mask-wearing': 603,
#  'device': 604,
#  'interrupt': 605,
#  'Khost': 606,
#  'parking': 607,
#  'chute': 608,
#  'Kofoworola': 609,
#  'Shaka': 610,
#  'Guggenheim': 611,
#  'Crisis': 612,
#  'hemisphere': 613,
#  'twins': 614,
#  '20-year-olds': 615,
#  'Hajan': 616,
#  'weeks': 617,
#  'Galan': 618,
#  'investing': 619,
#  'refloating': 620,
#  'opposition-controlled': 621,
#  'Wooten': 622,
#  'extended': 623,
#  'football': 624,
#  'assailed': 625,
#  'fishery': 626,
#  'Restoration': 627,
#  'apologies': 628,
#  'Sidr': 629,
#  'online': 630,
#  'Broad': 631,
#  'participating': 632,
#  'U-2': 633,
#  'gem-quality': 634,
#  'stomachs': 635,
#  'NFA': 636,
#  'refinances': 637,
#  '60th': 638,
#  '1,600-member': 639,
#  'Rebelde': 640,
#  'choosing': 641,
#  'ferrying': 642,
#  'Grujic': 643,
#  'Viktor': 644,
#  'slump': 645,
#  'baggage': 646,
#  'rumors': 647,
#  'Cambodia': 648,
#  '10-year': 649,
#  'embodied': 650,
#  '1': 651,
#  '2,47,000': 652,
#  'compensated': 653,
#  'Communists': 654,
#  'herdsmen': 655,
#  'neighbors': 656,
#  'Araft': 657,
#  'Polynesia': 658,
#  'shipyard': 659,
#  'collectivity': 660,
#  '255': 661,
#  'Azizullah': 662,
#  'gene': 663,
#  'infromation': 664,
#  '249-seat': 665,
#  'AIG': 666,
#  'lapsed': 667,
#  'Amen': 668,
#  'Stones': 669,
#  'orphanage': 670,
#  'spotting': 671,
#  '43,000': 672,
#  'Zhengyu': 673,
#  'Kikkan': 674,
#  'call': 675,
#  'Tropical': 676,
#  'Tzotzil': 677,
#  'unleash': 678,
#  'Alison': 679,
#  'piled': 680,
#  'fibroid': 681,
#  '3,200-strong': 682,
#  'tier': 683,
#  'Sharia': 684,
#  'answer': 685,
#  'Miro': 686,
#  'Superior': 687,
#  'stopover': 688,
#  'Mashonaland': 689,
#  'Sabri': 690,
#  'Boyle': 691,
#  '..': 692,
#  'small-': 693,
#  'Sherif': 694,
#  'Robitaille': 695,
#  'railed': 696,
#  'Starye': 697,
#  'da': 698,
#  'Tennessee': 699,
#  'SWALLOW': 700,
#  'Mardan': 701,
#  'reindeer': 702,
#  'ArmorGroup': 703,
#  'roast': 704,
#  'allowed': 705,
#  'municipal': 706,
#  'counterpart': 707,
#  'Qater': 708,
#  'Salas': 709,
#  'Pera': 710,
#  'billion': 711,
#  'Trawlers': 712,
#  'UN-organized': 713,
#  'Framework': 714,
#  'Abbott': 715,
#  'Tarasyuk': 716,
#  'netting': 717,
#  'titular': 718,
#  'Ambrosio': 719,
#  'orbits': 720,
#  'HIV': 721,
#  'interesting': 722,
#  'Newfoundland': 723,
#  'detected': 724,
#  '8,88,000': 725,
#  'function': 726,
#  'Zhaotong': 727,
#  'Kujundzic': 728,
#  'assist': 729,
#  'plague': 730,
#  'Egyptian-born': 731,
#  'Bud': 732,
#  'Momcilo': 733,
#  'dealers': 734,
#  'repair': 735,
#  'Delegation': 736,
#  'Wadia': 737,
#  'Gdansk': 738,
#  'erupted': 739,
#  'trailblazing': 740,
#  'number-five': 741,
#  '10-year-old': 742,
#  'Waldron': 743,
#  'Bourj': 744,
#  'Rodriguez': 745,
#  'Arms': 746,
#  'Acholi': 747,
#  'Haiphong': 748,
#  'Tomini': 749,
#  'paramedics': 750,
#  'Standby': 751,
#  'agreements': 752,
#  'Christa': 753,
#  'inside': 754,
#  'Aliyev': 755,
#  'Thousands': 756,
#  '52': 757,
#  'Domenici': 758,
#  'Architecture': 759,
#  'Ramsey': 760,
#  'Ariane': 761,
#  'lifetime': 762,
#  'Alps': 763,
#  'acquiring': 764,
#  'universal': 765,
#  'Shadid': 766,
#  'Afrikaner': 767,
#  'Yugoslav': 768,
#  'Gauthier': 769,
#  'Ushakov': 770,
#  '10-percent': 771,
#  'Budgetary': 772,
#  'Dushevina': 773,
#  'Institution': 774,
#  'There': 775,
#  'copy': 776,
#  '1844': 777,
#  'find': 778,
#  'Baaz': 779,
#  'Spirit': 780,
#  'conducted': 781,
#  'Mukherjee': 782,
#  'paving': 783,
#  'poverty-ridden': 784,
#  'T.': 785,
#  'despicable': 786,
#  'Attack': 787,
#  'al-Watan': 788,
#  'Arsamokov': 789,
#  'fruit': 790,
#  'absentia': 791,
#  'rehab': 792,
#  'stapler': 793,
#  '54th': 794,
#  'Patriotic': 795,
#  'respect': 796,
#  'pro-investment': 797,
#  'Eclair': 798,
#  'hideout': 799,
#  'Hamid': 800,
#  'Phillips': 801,
#  'Larkin': 802,
#  'Qinglin': 803,
#  'Khalidiyah': 804,
#  'governed': 805,
#  'Fourteen': 806,
#  'spots': 807,
#  'ascendant': 808,
#  '80,000': 809,
#  'simulated': 810,
#  'Helgesen': 811,
#  '17th-century': 812,
#  'benzene': 813,
#  'applied': 814,
#  'senate': 815,
#  '248': 816,
#  'racial': 817,
#  'milling': 818,
#  'Ukrainy': 819,
#  'Balakot': 820,
#  'Ahronot': 821,
#  'rebirth': 822,
#  '17-Jun': 823,
#  'CSW': 824,
#  'AIDS-related': 825,
#  'Iranians': 826,
#  'Guji': 827,
#  'strict': 828,
#  'Cristobal': 829,
#  'primacy': 830,
#  'Never': 831,
#  'subspecies': 832,
#  'armed': 833,
#  'Annan': 834,
#  'Kostomarov': 835,
#  'Dell': 836,
#  'Mireya': 837,
#  'alleges': 838,
#  'Nicobar': 839,
#  '73,000': 840,
#  'Montenegro': 841,
#  'innocence': 842,
#  'deputy-leader': 843,
#  'bluefin': 844,
#  'Kimi': 845,
#  'amounts': 846,
#  '100-year': 847,
#  'Mulally': 848,
#  'go-ahead': 849,
#  'diplomat': 850,
#  'Khakrez': 851,
#  'Aristolbulo': 852,
#  'al-Otari': 853,
#  'plagued': 854,
#  'Jesse': 855,
#  'untreated': 856,
#  'Grapes': 857,
#  'Hezbollah-operated': 858,
#  'beachfront': 859,
#  'Blige': 860,
#  'postponements': 861,
#  'notorious': 862,
#  'radicals': 863,
#  '167': 864,
#  'inconvenience': 865,
#  'Alvarezes': 866,
#  'patient': 867,
#  'sightings': 868,
#  'profiteers': 869,
#  'Malibu': 870,
#  'four-kilometer': 871,
#  'pre-condition': 872,
#  'backyard': 873,
#  'beasts': 874,
#  'fines': 875,
#  'half-century': 876,
#  'XP': 877,
#  'undermines': 878,
#  'identifying': 879,
#  'substance': 880,
#  'corn': 881,
#  'justified': 882,
#  'U.S.-Iraq': 883,
#  'Uddin': 884,
#  'passages': 885,
#  'Tribal': 886,
#  'deeds': 887,
#  'Wenesday': 888,
#  'Gilad': 889,
#  'roaring': 890,
#  '1772': 891,
#  'compounding': 892,
#  'timer': 893,
#  '196': 894,
#  'Organiation': 895,
#  'UNITA': 896,
#  'Ulus': 897,
#  'viewers': 898,
#  'midair': 899,
#  'chickens': 900,
#  '206': 901,
#  'seismologists': 902,
#  'Gedi': 903,
#  'adolescence': 904,
#  'Area': 905,
#  'hunger': 906,
#  'sway': 907,
#  'Bihar': 908,
#  'uncommon': 909,
#  'unfurled': 910,
#  'gnawed': 911,
#  '14-year': 912,
#  'Real': 913,
#  'limestone': 914,
#  'poultry': 915,
#  'newly-energized': 916,
#  'Abalo': 917,
#  'Areas': 918,
#  'whiten': 919,
#  'injury': 920,
#  'strangely': 921,
#  'butcher': 922,
#  'dramatically': 923,
#  'Lebanese': 924,
#  'indication': 925,
#  'evaluates': 926,
#  'sterilized': 927,
#  'Muqataa': 928,
#  'Islamophobic': 929,
#  'conservatives': 930,
#  'Panggabean': 931,
#  'account-holders': 932,
#  '03-Apr': 933,
#  'excited': 934,
#  'farmer': 935,
#  'isolation': 936,
#  'according': 937,
#  'liberalization': 938,
#  'bells': 939,
#  'Grozny': 940,
#  'Ibrahim': 941,
#  'dream': 942,
#  'Tahab': 943,
#  'Jong-Nam': 944,
#  'flood-stricken': 945,
#  'Jubran': 946,
#  'MSN': 947,
#  '1632': 948,
#  'powerlines': 949,
#  'Yoweri': 950,
#  'eruptions': 951,
#  '1845': 952,
#  'witness': 953,
#  'reconstructed': 954,
#  'eradicate': 955,
#  'constructing': 956,
#  'diminishes': 957,
#  'Banking': 958,
#  'spitting': 959,
#  'Islamiah': 960,
#  'frogs': 961,
#  'death': 962,
#  'commandos': 963,
#  'fat': 964,
#  'surveillance': 965,
#  'county': 966,
#  'Truck': 967,
#  'Argentines': 968,
#  'Yunnan': 969,
#  'crapping': 970,
#  'Textiles': 971,
#  'Iran': 972,
#  '2.00': 973,
#  'lightly': 974,
#  'formations': 975,
#  'Konstanz': 976,
#  'W.T.O': 977,
#  '1002': 978,
#  'Rebel': 979,
#  'kicks': 980,
#  'slate': 981,
#  'Bratislava-Trnava': 982,
#  'Town': 983,
#  'al-Chalabi': 984,
#  '314': 985,
#  'blacklist': 986,
#  'Bhaikaji': 987,
#  'resemble': 988,
#  'waited': 989,
#  'Heroes': 990,
#  'FARC': 991,
#  'Reference': 992,
#  'stern': 993,
#  'Arusha': 994,
#  'opponent': 995,
#  'serenaded': 996,
#  'contract-style': 997,
#  'is': 998,
#  'dollar-based': 999,
#  'streamlines': 1000,
#  ...}

# %% [markdown]
# ### Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ###  Building and Compiling a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 50, 50)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy",])

# %% [markdown]
# ###  Training the Model

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot import PlotLossesKerasTF

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min', metrics=["accuracy","val_accuracy"])

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesKerasTF(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.959, max:    0.989, cur:    0.989)
# 	validation       	 (min:    0.981, max:    0.986, cur:    0.986)
# Loss
# 	training         	 (min:    0.036, max:    0.179, cur:    0.036)
# 	validation       	 (min:    0.048, max:    0.067, cur:    0.048)
#
# Epoch 00003: val_loss improved from 0.05033 to 0.04786, saving model to model_weights.h5
# 1199/1199 [==============================] - 150s 125ms/step - loss: 0.0361 - accuracy: 0.9889 - val_loss: 0.0479 - val_accuracy: 0.9858
# Wall time: 8min 38s

# %% [markdown]
# ### Task 8: Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 [==============================] - 5s 18ms/step - loss: 0.0479 - accuracy: 0.9858
# [0.04785611107945442, 0.9857589602470398]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# At             O	O
# least          O	O
# eight          O	O
# people         O	O
# have           O	O
# been           O	O
# killed         O	O
# in             O	O
# the            O	O
# fighting       O	O
# .              O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
# sirens         O	O
